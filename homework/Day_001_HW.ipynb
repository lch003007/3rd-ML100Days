# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
def mean_absolute_error(y, yp):
    
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = sum(abs(y - yp)) / len(y)
    return mae

# 定義 mean_squared_error 這個函數, 計算並傳回 MSE
MAE = mean_absolute_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MAE))
def mean_squared_error(y,yp):
    """
    請完成這個 Function 後往下執行
    """
    mse = sum((y- yp)*(y-yp)) / len(y)
    return mse
# Out:
# The Mean absolute error is 11.023

# %%
w = 3
b = 0.5

x_lin = np.linspace(0,100,101)

y = (x_lin + np.random.randn(101) * 5 ) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assunme we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin,y,'b.',label = 'data')

plt.plot(x_lin,y_hat,'r-',label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 208.931
# The Mean absolute error is 11.023

# %%
"""
https://www.kaggle.com/c/titanic
1.你選的這組資料為何重要　
地球表面有70.8%都是海洋，但對於成長已久的人類仍是個神祕的謎團。
大海汪汪，舳艫千里，天有不測風雲。
這組數據讓不測的風雲得以預測
海上的生命安全

2.資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
英國貿易委員會的災難報告

3.蒐集而來的資料型態為何
結構化:數字

4.這組資料想解決的問題如何評估
問題:死亡率預測


"""
# Out:
# '\nhttps://www.kaggle.com/c/titanic\n1.你選的這組資料為何重要\u3000\n海上的生命安全\n\n2.資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)\n英國貿易委員會的災難報告\n\n3.蒐集而來的資料型態為何\n結構化:數字\n\n4.這組資料想解決的問題如何評估\n問題:死亡率預測\n\n\n'

# %%
"""
想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：

核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
自由載客車隊若是要爭取業績，那必須有良好的形象，以致人們在有需求時會優先想到我們。
然而還有很重要的一點就是車隊的數量，要有足夠的數量來應付人們以防供不應求。
核心問題：形象、車子/司機數量

資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
資料從ptt來，民眾最直接的發洩管道，可讓我們了解民眾對各大車隊的評價，可依照情況，擇其善者而從之，其不善者而改之。

蒐集而來的資料型態為何
結構化：文字

你要回答的問題，其如何評估 (tips：你的假設如何驗證)
以司機的平均收入來對比其他車隊的平均收入，來驗證是否可行。

"""
